# %% [markdown]
# # Run Streamlit Dashboard
#
# Run the cell below to launch the dashboard. It will open in your browser at `http://localhost:8501`.
#
# **To stop the dashboard:** Click the Stop button (⬛) next to the cell or restart the kernel.

# %%
# !pip install streamlit
# Out:
# ...
#      ---------------------------------------- 0.0/44.3 kB ? eta -:--:--
#      ---------------------------------------- 44.3/44.3 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.4 MB 7.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/10.4 MB 13.3 MB/s eta 0:00:01
#    ------- -------------------------------- 2.1/10.4 MB 16.5 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.4 MB 20.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.7/10.4 MB 21.5 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.4 MB 24.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.5/10.4 MB 24.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.2/10.4 MB 25.5 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.4 MB 26.2 MB/s eta 0:00:01
# ...

# %%
# %cd C:\Users\abhis\Desktop\thesis_project
# !streamlit run app.py
# Out:
# C:\Users\abhis\Desktop\thesis_project
